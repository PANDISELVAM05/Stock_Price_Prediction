# %%
# EXPLORATORY DATA ANALYSIS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_cleaned = pd.read_csv(r"D:\Gradtwin\Stock Price Prediction\Oil_Data_Cleaned.csv")

# =========================
# Step : Correlation Matrix
# =========================
corr_matrix = df_cleaned.corr(numeric_only=True)
# print("\nCorrelation Matrix (Numeric Columns):")
# print(corr_matrix)

plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Data Analysis

# %%
import pandas as pd

df=pd.read_csv('D:\Gradtwin\Stock Price Prediction\Oil_Data.csv')
df.head(10)
# Out:
#                         Date  Adj_Close      Close       High        Low  \
# 0  2000-08-23 00:00:00+00:00  32.049999  32.049999  32.799999  31.950001
# 1  2000-08-24 00:00:00+00:00  31.629999  31.629999  32.240002  31.400000
# 2  2000-08-25 00:00:00+00:00  32.049999  32.049999  32.099998  31.320000
# 3  2000-08-28 00:00:00+00:00  32.869999  32.869999  32.919998  31.860001
# 4  2000-08-29 00:00:00+00:00  32.720001  32.720001  33.029999  32.560001
# 5  2000-08-30 00:00:00+00:00  33.400002  33.400002  33.400002  32.099998
# 6  2000-08-31 00:00:00+00:00  33.099998  33.099998  33.700001  32.970001
# 7  2000-09-01 00:00:00+00:00  33.380001  33.380001  33.450001  32.750000
# 8  2000-09-05 00:00:00+00:00  33.799999  33.799999  33.990002  33.419998
# 9  2000-09-06 00:00:00+00:00  34.950001  34.950001  34.950001  33.830002
#
#         Open  Volume
# 0  31.950001   79385
# 1  31.900000   72978
# 2  31.700001   44601
# 3  32.040001   46770
# 4  32.820000   49131
# 5  32.750000   79214
# 6  33.250000   56895
# 7  33.049999   45869
# 8  33.950001   55722
# 9  33.990002   74692

# %%
for col in df.columns:
    print('Unique values of ' + col)
    print(df[col].unique())
    print("======================")
# Out:
# Unique values of Date
# ['2000-08-23 00:00:00+00:00' '2000-08-24 00:00:00+00:00'
#  '2000-08-25 00:00:00+00:00' ... '2024-10-28 00:00:00+00:00'
#  '2024-10-29 00:00:00+00:00' '2024-10-30 00:00:00+00:00']
# ======================
# Unique values of Adj_Close
# [32.04999924 31.62999916 32.86999893 ... 69.22000122 72.08999634
#  67.20999908]
# ======================
# Unique values of Close
# [32.04999924 31.62999916 32.86999893 ... 69.22000122 72.08999634
#  67.20999908]
# ======================
# Unique values of High
# [32.79999924 32.24000168 32.09999847 ... 72.12000275 71.11000061
#  71.02999878]
# ======================
# Unique values of Low
# [31.95000076 31.39999962 31.31999969 ... 68.69000244 69.95999908
#  67.27999878]
# ======================
# Unique values of Open
# [31.95000076 31.89999962 31.70000076 ... 68.98000336 68.01999664
#  67.47000122]
# ======================
# Unique values of Volume
# [ 79385  72978  44601 ... 419623 291929 284795]
# ======================

# %%
df[df['Date'] == '2010-01-01']
# Out:
# Empty DataFrame
# Columns: [Date, Adj_Close, Close, High, Low, Open, Volume]
# Index: []
